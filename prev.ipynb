# %% [markdown]
# **Initialization**

# %%
import google.generativeai as genai
import json
import os
from dotenv import load_dotenv
import easyocr
import cv2
from rapidfuzz import fuzz

load_dotenv()
# Out:
# True

# %% [markdown]
# **Gemini Model**

# %%
def generate(prompt, image_path) -> list | dict:
    api_key = os.getenv("GEMINI_API_KEY")
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel(
        model_name="gemini-2.5-flash",
        system_instruction="You are a helpful assistant that extracts newspaper fields from images.",
        generation_config={"response_mime_type": "application/json"}
    )

    with open(image_path, "rb") as image_file:
        image_bytes = image_file.read()

    response = model.generate_content([
        {"text": prompt},
        {"mime_type": "image/png", "data": image_bytes}
    ])

    raw_json = response.text
    data = json.loads(raw_json)

    return data

# %% [markdown]
# **Call to generate headline from Gemini**

# %%
headline_schema = {
	"type": "array",
	"items": {"type": "string"}
}

headline_prompt = (
	"You are given a newspaper image. "
	"Extract only the article all possible headlines — ignore advertisements, captions, subheadlines, and any other text. "
	"Return the result strictly matching this JSON schema:\n\n"
	f"{json.dumps(headline_schema, indent=2)}"
)

target_image_path = "page_17.png"

headlines = generate(headline_prompt, target_image_path)

for i, headline in enumerate(headlines):
    headlines[i] = headline
print(headlines)
# Dev log
print(json.dumps(headlines, indent=2, ensure_ascii=False))
# Out:
# ['OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS', 'DILG: Full-blast probe on public funds misuse', 'Poor flood-control partly due to budget insertions—DPWH', 'Human skull, teeth from Taal Lake raise hope for DNA—DOJ', "Pres'l adviser, 2 others charged with indirect contempt before SC", 'House elects new committee heads']
# [
#   "OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS",
#   "DILG: Full-blast probe on public funds misuse",
#   "Poor flood-control partly due to budget insertions—DPWH",
#   "Human skull, teeth from Taal Lake raise hope for DNA—DOJ",
#   "Pres'l adviser, 2 others charged with indirect contempt before SC",
#   "House elects new committee heads"
# ]

# %% [markdown]
# **EasyOCR reads**

# %%
reader = easyocr.Reader(['en'])
image = cv2.imread(target_image_path)
results = reader.readtext(image)

image_raw = image.copy()
for (top_left, top_right, bottom_right, bottom_left), text, confidence in results:
    tl = (int(top_left[0]), int(top_left[1]))
    br = (int(bottom_right[0]), int(bottom_right[1]))
    cv2.rectangle(image_raw, tl, br, (0, 0, 255), 2)
    coord_label = f"{tl} {br}"
    cv2.putText(image_raw, coord_label, (tl[0], tl[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

output_path_raw = target_image_path.replace(".png", "_ocr_boxes.png")
cv2.imwrite(output_path_raw, image_raw)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# True

# %% [markdown]
# **Filter out text that matches with the list of headlines from Gemini**

# %%
bounding_box_text = []
bounding_box_coordinates = []

for coordinates, text, _ in results:
    
    for headline in headlines:
        score = fuzz.partial_ratio(headline, text)
        if score > 80:
            print(text)
            top_left, _, bottom_right, _ = coordinates
            
            current_box = ((int(top_left[0]), int(top_left[1])),
                           (int(bottom_right[0]), int(bottom_right[1])))
            bounding_box_text.append(text)
            bounding_box_coordinates.append(current_box)
# Out:
# OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS
# the
# within
# OCTA
# public
# Poor flood-control
# DILG: Full-blast probe
# partly due to budget
# insertions
# DPWH
# on
# on
# on
# public funds misuse
# Public
# the
# an
# a
# a
# a
# a
# a
# the
# Human skull, teeth from Taal
# Lake raise hope for DNA-_DOJ
# Taal Lake
# DNA
# from
# the
# within
# Pres'I adviser; 2 others charged
# House elects new
# with indirect contempt before SC
# committeeheads
# committees
# in
# in
# contempt

# %%
def is_close(coordinate1, coordinate2, gap_x=5, gap_y=20):
    (x1_min, y1_min), (x1_max, y1_max) = coordinate1
    (x2_min, y2_min), (x2_max, y2_max) = coordinate2

    # Expand both boxes by the gap
    x1_min, y1_min, x1_max, y1_max = x1_min - gap_x, y1_min - gap_y, x1_max + gap_x, y1_max + gap_y
    x2_min, y2_min, x2_max, y2_max = x2_min - gap_x, y2_min - gap_y, x2_max + gap_x, y2_max + gap_y

    # Overlap condition (after expansion)
    horizontal_overlap = not (x1_max < x2_min or x2_max < x1_min)
    vertical_overlap = not (y1_max < y2_min or y2_max < y1_min)

    return horizontal_overlap and vertical_overlap

new = {}
print("Headlines:", headlines)
for headline in headlines:
    new[headline] = []

for i, text in enumerate(bounding_box_text):
    box = bounding_box_coordinates[i]
    for headline in new:
        score = fuzz.partial_ratio(headline, text)
        if score > 80:
            headline.replace(text, "")
            print(f"{headline=}")
            if not new[headline]:
                new[headline].append({"text": text, "box": box})
                print("new")
                print(f"{text=}, {box=}")
            else:
                for i, currentBox in enumerate(new[headline]):
                    score = fuzz.ratio(new[headline][i]["text"], headline)
                    print(f"{text=}, {box=}, {currentBox=}, {score=}")
                    if score >= 90:
                        break
                    if is_close(currentBox["box"], box):
                        
                        (ex_tl_x, ex_tl_y), (ex_br_x, ex_br_y) = currentBox["box"]
                        (tl_x, tl_y), (br_x, br_y) = box

                        new_tl = (min(ex_tl_x, tl_x), min(ex_tl_y, tl_y))
                        new_br = (max(ex_br_x, br_x), max(ex_br_y, br_y))

                        new[headline][i]["box"] = (new_tl, new_br)
                        new[headline][i]["text"] += " " + text
                        break
                else:
                    new[headline].append({"text": text, "box": box})

print(json.dumps(new, indent=2, ensure_ascii=False))
# Out:
# Headlines: ['OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS', 'DILG: Full-blast probe on public funds misuse', 'Poor flood-control partly due to budget insertions—DPWH', 'Human skull, teeth from Taal Lake raise hope for DNA—DOJ', "Pres'l adviser, 2 others charged with indirect contempt before SC", 'House elects new committee heads']
# headline='OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS'
# new
# text='OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS', box=((174, 502), (3574, 685))
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# new
# text='the', box=((1014, 967), (1073, 1010))
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='within', box=((1362, 967), (1474, 1004)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# headline='OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS'
# text='OCTA', box=((466, 1146), (577, 1189)), currentBox={'text': 'OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS', 'box': ((174, 502), (3574, 685))}, score=100.0
# headline='DILG: Full-blast probe on public funds misuse'
# new
# text='public', box=((1354, 1326), (1476, 1382))
# headline='Poor flood-control partly due to budget insertions—DPWH'
# new
# text='Poor flood-control', box=((3002, 1504), (3573, 1617))
# headline='DILG: Full-blast probe on public funds misuse'
# text='DILG: Full-blast probe', box=((96, 1455), (2800, 1894)), currentBox={'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, score=23.529411764705888
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='partly due to budget', box=((2986, 1613), (3644, 1747)), currentBox={'text': 'Poor flood-control', 'box': ((3002, 1504), (3573, 1617))}, score=49.31506849315068
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='insertions', box=((2997, 1748), (3324, 1848)), currentBox={'text': 'Poor flood-control partly due to budget', 'box': ((2986, 1504), (3644, 1747))}, score=82.97872340425532
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='DPWH', box=((3392, 1731), (3621, 1844)), currentBox={'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}, score=95.23809523809523
# headline='DILG: Full-blast probe on public funds misuse'
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, score=23.529411764705888
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'DILG: Full-blast probe', 'box': ((96, 1455), (2800, 1894))}, score=65.67164179104478
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}, score=95.23809523809523
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# headline='DILG: Full-blast probe on public funds misuse'
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, score=23.529411764705888
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'DILG: Full-blast probe on', 'box': ((95, 1455), (2800, 2186))}, score=71.42857142857143
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}, score=95.23809523809523
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'on', 'box': ((95, 1885), (468, 2186))}, score=5.970149253731338
# headline='DILG: Full-blast probe on public funds misuse'
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, score=23.529411764705888
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'DILG: Full-blast probe on on', 'box': ((95, 1455), (2800, 2186))}, score=73.97260273972603
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}, score=95.23809523809523
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='on', box=((95, 1885), (468, 2186)), currentBox={'text': 'on on', 'box': ((95, 1885), (468, 2186))}, score=14.28571428571429
# headline='DILG: Full-blast probe on public funds misuse'
# text='public funds misuse', box=((430, 1769), (2963, 2252)), currentBox={'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, score=23.529411764705888
# text='public funds misuse', box=((430, 1769), (2963, 2252)), currentBox={'text': 'DILG: Full-blast probe on on on', 'box': ((95, 1455), (2800, 2186))}, score=73.6842105263158
# headline='DILG: Full-blast probe on public funds misuse'
# text='Public', box=((3393, 2127), (3509, 2170)), currentBox={'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, score=23.529411764705888
# text='Public', box=((3393, 2127), (3509, 2170)), currentBox={'text': 'DILG: Full-blast probe on on on public funds misuse', 'box': ((95, 1455), (2963, 2252))}, score=93.75
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='the', box=((3240, 2359), (3298, 2397)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='the', box=((3240, 2359), (3298, 2397)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='the', box=((3240, 2359), (3298, 2397)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# headline='Human skull, teeth from Taal Lake raise hope for DNA—DOJ'
# new
# text='an', box=((112, 3270), (178, 3320))
# headline='DILG: Full-blast probe on public funds misuse'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, score=23.529411764705888
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'DILG: Full-blast probe on on on public funds misuse', 'box': ((95, 1455), (2963, 2252))}, score=93.75
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}, score=95.23809523809523
# headline='Human skull, teeth from Taal Lake raise hope for DNA—DOJ'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'an', 'box': ((112, 3270), (178, 3320))}, score=6.896551724137934
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# headline='House elects new committee heads'
# new
# text='a', box=((119, 3409), (149, 3450))
# headline='DILG: Full-blast probe on public funds misuse'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, score=23.529411764705888
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'DILG: Full-blast probe on on on public funds misuse', 'box': ((95, 1455), (2963, 2252))}, score=93.75
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}, score=95.23809523809523
# headline='Human skull, teeth from Taal Lake raise hope for DNA—DOJ'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'an', 'box': ((112, 3270), (178, 3320))}, score=6.896551724137934
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'a', 'box': ((119, 3409), (149, 3450))}, score=3.508771929824561
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'a', 'box': ((119, 3409), (149, 3450))}, score=3.0303030303030276
# headline='House elects new committee heads'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'a', 'box': ((119, 3409), (149, 3450))}, score=6.060606060606055
# headline='DILG: Full-blast probe on public funds misuse'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, score=23.529411764705888
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'DILG: Full-blast probe on on on public funds misuse', 'box': ((95, 1455), (2963, 2252))}, score=93.75
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}, score=95.23809523809523
# headline='Human skull, teeth from Taal Lake raise hope for DNA—DOJ'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'an', 'box': ((112, 3270), (178, 3320))}, score=6.896551724137934
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'a a', 'box': ((119, 3409), (149, 3450))}, score=10.169491525423723
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'a a', 'box': ((119, 3409), (149, 3450))}, score=8.823529411764708
# headline='House elects new committee heads'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'a a', 'box': ((119, 3409), (149, 3450))}, score=11.428571428571432
# headline='DILG: Full-blast probe on public funds misuse'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, score=23.529411764705888
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'DILG: Full-blast probe on on on public funds misuse', 'box': ((95, 1455), (2963, 2252))}, score=93.75
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}, score=95.23809523809523
# headline='Human skull, teeth from Taal Lake raise hope for DNA—DOJ'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'an', 'box': ((112, 3270), (178, 3320))}, score=6.896551724137934
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'a a a', 'box': ((119, 3409), (149, 3450))}, score=16.393442622950815
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'a a a', 'box': ((119, 3409), (149, 3450))}, score=11.428571428571432
# headline='House elects new committee heads'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'a a a', 'box': ((119, 3409), (149, 3450))}, score=16.216216216216218
# headline='DILG: Full-blast probe on public funds misuse'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, score=23.529411764705888
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'DILG: Full-blast probe on on on public funds misuse', 'box': ((95, 1455), (2963, 2252))}, score=93.75
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}, score=95.23809523809523
# headline='Human skull, teeth from Taal Lake raise hope for DNA—DOJ'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'an', 'box': ((112, 3270), (178, 3320))}, score=6.896551724137934
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'a a a a', 'box': ((119, 3409), (149, 3450))}, score=22.22222222222222
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'a a a a', 'box': ((119, 3409), (149, 3450))}, score=13.888888888888884
# headline='House elects new committee heads'
# text='a', box=((119, 3409), (149, 3450)), currentBox={'text': 'a a a a', 'box': ((119, 3409), (149, 3450))}, score=20.512820512820518
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='the', box=((413, 3662), (477, 3699)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='the', box=((413, 3662), (477, 3699)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='the', box=((413, 3662), (477, 3699)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text='the', box=((413, 3662), (477, 3699)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# text='the', box=((413, 3662), (477, 3699)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=16.216216216216218
# headline='Human skull, teeth from Taal Lake raise hope for DNA—DOJ'
# text='Human skull, teeth from Taal', box=((2277, 4360), (3549, 4498)), currentBox={'text': 'an', 'box': ((112, 3270), (178, 3320))}, score=6.896551724137934
# text='Human skull, teeth from Taal', box=((2277, 4360), (3549, 4498)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=24.615384615384617
# headline='Human skull, teeth from Taal Lake raise hope for DNA—DOJ'
# text='Lake raise hope for DNA-_DOJ', box=((2275, 4501), (3630, 4664)), currentBox={'text': 'an', 'box': ((112, 3270), (178, 3320))}, score=6.896551724137934
# text='Lake raise hope for DNA-_DOJ', box=((2275, 4501), (3630, 4664)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=24.615384615384617
# text='Lake raise hope for DNA-_DOJ', box=((2275, 4501), (3630, 4664)), currentBox={'text': 'Human skull, teeth from Taal', 'box': ((2277, 4360), (3549, 4498))}, score=66.66666666666667
# headline='Human skull, teeth from Taal Lake raise hope for DNA—DOJ'
# text='Taal Lake', box=((2280, 4885), (2460, 4928)), currentBox={'text': 'an', 'box': ((112, 3270), (178, 3320))}, score=6.896551724137934
# text='Taal Lake', box=((2280, 4885), (2460, 4928)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=24.615384615384617
# text='Taal Lake', box=((2280, 4885), (2460, 4928)), currentBox={'text': 'Human skull, teeth from Taal Lake raise hope for DNA-_DOJ', 'box': ((2275, 4360), (3630, 4664))}, score=97.34513274336283
# headline='Human skull, teeth from Taal Lake raise hope for DNA—DOJ'
# text='DNA', box=((2280, 4927), (2376, 4970)), currentBox={'text': 'an', 'box': ((112, 3270), (178, 3320))}, score=6.896551724137934
# text='DNA', box=((2280, 4927), (2376, 4970)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=24.615384615384617
# text='DNA', box=((2280, 4927), (2376, 4970)), currentBox={'text': 'Human skull, teeth from Taal Lake raise hope for DNA-_DOJ', 'box': ((2275, 4360), (3630, 4664))}, score=97.34513274336283
# headline='Human skull, teeth from Taal Lake raise hope for DNA—DOJ'
# text='from', box=((2580, 4932), (2671, 4970)), currentBox={'text': 'an', 'box': ((112, 3270), (178, 3320))}, score=6.896551724137934
# text='from', box=((2580, 4932), (2671, 4970)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=24.615384615384617
# text='from', box=((2580, 4932), (2671, 4970)), currentBox={'text': 'Human skull, teeth from Taal Lake raise hope for DNA-_DOJ', 'box': ((2275, 4360), (3630, 4664))}, score=97.34513274336283
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='the', box=((2681, 4932), (2745, 4970)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='the', box=((2681, 4932), (2745, 4970)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='the', box=((2681, 4932), (2745, 4970)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text='the', box=((2681, 4932), (2745, 4970)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# text='the', box=((2681, 4932), (2745, 4970)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=16.216216216216218
# text='the', box=((2681, 4932), (2745, 4970)), currentBox={'text': 'the', 'box': ((413, 3662), (477, 3699))}, score=8.823529411764708
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='within', box=((3008, 5054), (3119, 5097)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='within', box=((3008, 5054), (3119, 5097)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='within', box=((3008, 5054), (3119, 5097)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text='within', box=((3008, 5054), (3119, 5097)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# text='within', box=((3008, 5054), (3119, 5097)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=16.216216216216218
# text='within', box=((3008, 5054), (3119, 5097)), currentBox={'text': 'the', 'box': ((413, 3662), (477, 3699))}, score=8.823529411764708
# text='within', box=((3008, 5054), (3119, 5097)), currentBox={'text': 'the', 'box': ((2681, 4932), (2745, 4970))}, score=8.823529411764708
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text="Pres'I adviser; 2 others charged", box=((103, 5793), (1394, 5956)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text="Pres'I adviser; 2 others charged", box=((103, 5793), (1394, 5956)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text="Pres'I adviser; 2 others charged", box=((103, 5793), (1394, 5956)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text="Pres'I adviser; 2 others charged", box=((103, 5793), (1394, 5956)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# text="Pres'I adviser; 2 others charged", box=((103, 5793), (1394, 5956)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=16.216216216216218
# text="Pres'I adviser; 2 others charged", box=((103, 5793), (1394, 5956)), currentBox={'text': 'the', 'box': ((413, 3662), (477, 3699))}, score=8.823529411764708
# text="Pres'I adviser; 2 others charged", box=((103, 5793), (1394, 5956)), currentBox={'text': 'the', 'box': ((2681, 4932), (2745, 4970))}, score=8.823529411764708
# text="Pres'I adviser; 2 others charged", box=((103, 5793), (1394, 5956)), currentBox={'text': 'within', 'box': ((3008, 5054), (3119, 5097))}, score=16.901408450704224
# headline='House elects new committee heads'
# text='House elects new', box=((1573, 5828), (2160, 5941)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=24.390243902439025
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='with indirect contempt before SC', box=((101, 5902), (1481, 6083)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='with indirect contempt before SC', box=((101, 5902), (1481, 6083)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='with indirect contempt before SC', box=((101, 5902), (1481, 6083)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text='with indirect contempt before SC', box=((101, 5902), (1481, 6083)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# text='with indirect contempt before SC', box=((101, 5902), (1481, 6083)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=16.216216216216218
# text='with indirect contempt before SC', box=((101, 5902), (1481, 6083)), currentBox={'text': 'the', 'box': ((413, 3662), (477, 3699))}, score=8.823529411764708
# text='with indirect contempt before SC', box=((101, 5902), (1481, 6083)), currentBox={'text': 'the', 'box': ((2681, 4932), (2745, 4970))}, score=8.823529411764708
# text='with indirect contempt before SC', box=((101, 5902), (1481, 6083)), currentBox={'text': 'within', 'box': ((3008, 5054), (3119, 5097))}, score=16.901408450704224
# text='with indirect contempt before SC', box=((101, 5902), (1481, 6083)), currentBox={'text': "Pres'I adviser; 2 others charged", 'box': ((103, 5793), (1394, 5956))}, score=61.855670103092784
# headline='House elects new committee heads'
# text='committeeheads', box=((1567, 5949), (2165, 6062)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=24.390243902439025
# text='committeeheads', box=((1567, 5949), (2165, 6062)), currentBox={'text': 'House elects new', 'box': ((1573, 5828), (2160, 5941))}, score=66.66666666666667
# headline='House elects new committee heads'
# text='committees', box=((1584, 6304), (1785, 6341)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=24.390243902439025
# text='committees', box=((1584, 6304), (1785, 6341)), currentBox={'text': 'House elects new committeeheads', 'box': ((1567, 5828), (2165, 6062))}, score=98.41269841269842
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}, score=95.23809523809523
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=16.216216216216218
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'the', 'box': ((413, 3662), (477, 3699))}, score=8.823529411764708
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'the', 'box': ((2681, 4932), (2745, 4970))}, score=8.823529411764708
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'within', 'box': ((3008, 5054), (3119, 5097))}, score=16.901408450704224
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': "Pres'I adviser; 2 others charged with indirect contempt before SC", 'box': ((101, 5793), (1481, 6083))}, score=96.92307692307692
# headline='Poor flood-control partly due to budget insertions—DPWH'
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}, score=95.23809523809523
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=16.216216216216218
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'the', 'box': ((413, 3662), (477, 3699))}, score=8.823529411764708
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'the', 'box': ((2681, 4932), (2745, 4970))}, score=8.823529411764708
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': 'within', 'box': ((3008, 5054), (3119, 5097))}, score=16.901408450704224
# text='in', box=((1795, 6304), (1838, 6341)), currentBox={'text': "Pres'I adviser; 2 others charged with indirect contempt before SC", 'box': ((101, 5793), (1481, 6083))}, score=96.92307692307692
# headline="Pres'l adviser, 2 others charged with indirect contempt before SC"
# text='contempt', box=((587, 6346), (757, 6383)), currentBox={'text': 'the', 'box': ((1014, 967), (1073, 1010))}, score=8.823529411764708
# text='contempt', box=((587, 6346), (757, 6383)), currentBox={'text': 'within', 'box': ((1362, 967), (1474, 1004))}, score=16.901408450704224
# text='contempt', box=((587, 6346), (757, 6383)), currentBox={'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, score=19.17808219178082
# text='contempt', box=((587, 6346), (757, 6383)), currentBox={'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, score=8.823529411764708
# text='contempt', box=((587, 6346), (757, 6383)), currentBox={'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, score=16.216216216216218
# text='contempt', box=((587, 6346), (757, 6383)), currentBox={'text': 'the', 'box': ((413, 3662), (477, 3699))}, score=8.823529411764708
# text='contempt', box=((587, 6346), (757, 6383)), currentBox={'text': 'the', 'box': ((2681, 4932), (2745, 4970))}, score=8.823529411764708
# text='contempt', box=((587, 6346), (757, 6383)), currentBox={'text': 'within', 'box': ((3008, 5054), (3119, 5097))}, score=16.901408450704224
# text='contempt', box=((587, 6346), (757, 6383)), currentBox={'text': "Pres'I adviser; 2 others charged with indirect contempt before SC", 'box': ((101, 5793), (1481, 6083))}, score=96.92307692307692
# {
#   "OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS": [
#     {
#       "text": "OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS",
#       "box": [
#         [
#           174,
#           502
#         ],
#         [
#           3574,
#           685
#         ]
#       ]
#     }
#   ],
#   "DILG: Full-blast probe on public funds misuse": [
#     {
#       "text": "public",
#       "box": [
#         [
#           1354,
#           1326
#         ],
#         [
#           1476,
#           1382
#         ]
#       ]
#     },
#     {
#       "text": "DILG: Full-blast probe on on on public funds misuse",
#       "box": [
#         [
#           95,
#           1455
#         ],
#         [
#           2963,
#           2252
#         ]
#       ]
#     }
#   ],
#   "Poor flood-control partly due to budget insertions—DPWH": [
#     {
#       "text": "Poor flood-control partly due to budget insertions",
#       "box": [
#         [
#           2986,
#           1504
#         ],
#         [
#           3644,
#           1848
#         ]
#       ]
#     }
#   ],
#   "Human skull, teeth from Taal Lake raise hope for DNA—DOJ": [
#     {
#       "text": "an",
#       "box": [
#         [
#           112,
#           3270
#         ],
#         [
#           178,
#           3320
#         ]
#       ]
#     },
#     {
#       "text": "a a a a a",
#       "box": [
#         [
#           119,
#           3409
#         ],
#         [
#           149,
#           3450
#         ]
#       ]
#     },
#     {
#       "text": "Human skull, teeth from Taal Lake raise hope for DNA-_DOJ",
#       "box": [
#         [
#           2275,
#           4360
#         ],
#         [
#           3630,
#           4664
#         ]
#       ]
#     }
#   ],
#   "Pres'l adviser, 2 others charged with indirect contempt before SC": [
#     {
#       "text": "the",
#       "box": [
#         [
#           1014,
#           967
#         ],
#         [
#           1073,
#           1010
#         ]
#       ]
#     },
#     {
#       "text": "within",
#       "box": [
#         [
#           1362,
#           967
#         ],
#         [
#           1474,
#           1004
#         ]
#       ]
#     },
#     {
#       "text": "on on on",
#       "box": [
#         [
#           95,
#           1885
#         ],
#         [
#           468,
#           2186
#         ]
#       ]
#     },
#     {
#       "text": "the",
#       "box": [
#         [
#           3240,
#           2359
#         ],
#         [
#           3298,
#           2397
#         ]
#       ]
#     },
#     {
#       "text": "a a a a a",
#       "box": [
#         [
#           119,
#           3409
#         ],
#         [
#           149,
#           3450
#         ]
#       ]
#     },
#     {
#       "text": "the",
#       "box": [
#         [
#           413,
#           3662
#         ],
#         [
#           477,
#           3699
#         ]
#       ]
#     },
#     {
#       "text": "the",
#       "box": [
#         [
#           2681,
#           4932
#         ],
#         [
#           2745,
#           4970
#         ]
#       ]
#     },
#     {
#       "text": "within",
#       "box": [
#         [
#           3008,
#           5054
#         ],
#         [
#           3119,
#           5097
#         ]
#       ]
#     },
#     {
#       "text": "Pres'I adviser; 2 others charged with indirect contempt before SC",
#       "box": [
#         [
#           101,
#           5793
#         ],
#         [
#           1481,
#           6083
#         ]
#       ]
#     }
#   ],
#   "House elects new committee heads": [
#     {
#       "text": "a a a a a",
#       "box": [
#         [
#           119,
#           3409
#         ],
#         [
#           149,
#           3450
#         ]
#       ]
#     },
#     {
#       "text": "House elects new committeeheads",
#       "box": [
#         [
#           1567,
#           5828
#         ],
#         [
#           2165,
#           6062
#         ]
#       ]
#     }
#   ]
# }

# %%
for key in new:
    print(new[key])
    for i in range(len(new[key])):
        for j in range(i + 1, len(new[key])):
            if is_close(new[key][i]["box"], new[key][j]["box"]):
                print(f"Merging {new[key][i]} and {new[key][j]}")
                (ex_tl_x, ex_tl_y), (ex_br_x, ex_br_y) = new[key][i]["box"]
                (tl_x, tl_y), (br_x, br_y) = new[key][j]["box"]

                new_tl = (min(ex_tl_x, tl_x), min(ex_tl_y, tl_y))
                new_br = (max(ex_br_x, br_x), max(ex_br_y, br_y))

                new[key][i]["box"] = (new_tl, new_br)
                new[key][i]["text"] += " " + new[key][j]["text"]
                del new[key][j]
                break
print(new)
# Out:
# [{'text': 'OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS', 'box': ((174, 502), (3574, 685))}]
# [{'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, {'text': 'DILG: Full-blast probe on on on public funds misuse', 'box': ((95, 1455), (2963, 2252))}]
# [{'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}]
# [{'text': 'an', 'box': ((112, 3270), (178, 3320))}, {'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, {'text': 'Human skull, teeth from Taal Lake raise hope for DNA-_DOJ', 'box': ((2275, 4360), (3630, 4664))}]
# [{'text': 'the', 'box': ((1014, 967), (1073, 1010))}, {'text': 'within', 'box': ((1362, 967), (1474, 1004))}, {'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, {'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, {'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, {'text': 'the', 'box': ((413, 3662), (477, 3699))}, {'text': 'the', 'box': ((2681, 4932), (2745, 4970))}, {'text': 'within', 'box': ((3008, 5054), (3119, 5097))}, {'text': "Pres'I adviser; 2 others charged with indirect contempt before SC", 'box': ((101, 5793), (1481, 6083))}]
# [{'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, {'text': 'House elects new committeeheads', 'box': ((1567, 5828), (2165, 6062))}]
# {'OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS': [{'text': 'OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS', 'box': ((174, 502), (3574, 685))}], 'DILG: Full-blast probe on public funds misuse': [{'text': 'public', 'box': ((1354, 1326), (1476, 1382))}, {'text': 'DILG: Full-blast probe on on on public funds misuse', 'box': ((95, 1455), (2963, 2252))}], 'Poor flood-control partly due to budget insertions—DPWH': [{'text': 'Poor flood-control partly due to budget insertions', 'box': ((2986, 1504), (3644, 1848))}], 'Human skull, teeth from Taal Lake raise hope for DNA—DOJ': [{'text': 'an', 'box': ((112, 3270), (178, 3320))}, {'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, {'text': 'Human skull, teeth from Taal Lake raise hope for DNA-_DOJ', 'box': ((2275, 4360), (3630, 4664))}], "Pres'l adviser, 2 others charged with indirect contempt before SC": [{'text': 'the', 'box': ((1014, 967), (1073, 1010))}, {'text': 'within', 'box': ((1362, 967), (1474, 1004))}, {'text': 'on on on', 'box': ((95, 1885), (468, 2186))}, {'text': 'the', 'box': ((3240, 2359), (3298, 2397))}, {'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, {'text': 'the', 'box': ((413, 3662), (477, 3699))}, {'text': 'the', 'box': ((2681, 4932), (2745, 4970))}, {'text': 'within', 'box': ((3008, 5054), (3119, 5097))}, {'text': "Pres'I adviser; 2 others charged with indirect contempt before SC", 'box': ((101, 5793), (1481, 6083))}], 'House elects new committee heads': [{'text': 'a a a a a', 'box': ((119, 3409), (149, 3450))}, {'text': 'House elects new committeeheads', 'box': ((1567, 5828), (2165, 6062))}]}

# %%
from fuzzywuzzy import process

image_merged = image.copy()

for key in new:
    query = key
    choices = [i["text"] for i in new[key]]


    if not choices:
        continue  # skip if no choices

    # map choice → index
    choices_dict = {c: i for i, c in enumerate(choices)}

    # get best match
    best_match = process.extractOne(query, list(choices_dict.keys()))
    if best_match:
        text, score = best_match
        index = choices_dict[text]
        tl, br = new[key][index]["box"]
        cv2.rectangle(image_merged, tl, br, (0, 255, 0), 5)

# save output
output_path_merged = f"{os.path.splitext(target_image_path)[0]}_result{os.path.splitext(target_image_path)[1]}"
cv2.imwrite(output_path_merged, image_merged)
# Out:
# True

# %% [markdown]
# **Generate Byline from Gemini**

# %%
byline_schema = {
    "type": "array",
    "items": {
        "type": "object",
        "properties": {
            "headline": {"type": "string"},
            "byline": {"type": "string"},
        },
        "required": ["headline", "byline"]
    }
}

byline_prompt = (
	"You are given a newspaper image. "
	"Extract only the article's byline or author from the given headlines — ignore advertisements, captions, subheadlines, and any other text. "
    "use the following headlines to find the bylines: "
    f"{json.dumps(headlines, indent=2)}. "
	"Return the result strictly matching this JSON schema:\n\n"
	f"{json.dumps(byline_schema, indent=2)}"
)

bylines = generate(byline_prompt, target_image_path)

print(json.dumps(bylines, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "headline": "OCTA SURVEY SHOWS UPTICK IN PBBM, SPEAKER RATINGS",
#     "byline": "By Rex Espiritu and Maricel V. Cruz"
#   },
#   {
#     "headline": "DILG: Full-blast probe on public funds misuse",
#     "byline": "By Rex Espiritu, Pot Chavez and Vito Barcelo"
#   },
#   {
#     "headline": "Poor flood-control partly due to budget insertions—DPWH",
#     "byline": "By Vito Barcelo, Ram Superable, and Maricel V. Cruz"
#   },
#   {
#     "headline": "Human skull, teeth from Taal Lake raise hope for DNA—DOJ",
#     "byline": "By Pot Chavez"
#   },
#   {
#     "headline": "Pres'l adviser, 2 others charged with indirect contempt before SC",
#     "byline": "By Pot Chavez, Vito Barcelo, and Ram Superable"
#   },
#   {
#     "headline": "House elects new committee heads",
#     "byline": "By Maricel V. Cruz"
#   }
# ]
